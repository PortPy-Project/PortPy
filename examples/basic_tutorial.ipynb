# %% [markdown]
# # <center>Basic Tutorial </center>
#
#
# ### This example demonstrates the following main functionalities of portpy_photon:
#
#
# 1. Accessing the curated portpy data
#     (DataExplorer class)
#
# 2. Creating a simple IMRT plan
#     (Plan class, Optimization class)
#
# 3. Visualising the plan (e.g., dose distribution, fluence, DVH)
#    (Visualization class)
#
# 4. Evaluating the plan (e.g., max/mean/DVH points, established clinical metrics)
#     (Evaluation class)
#
# 5. Saving the plan and solution for future uses
#     (Utils)
#
# 6. Advanced plan visualization through integration with a popular 3D-Slicer package
#     (Visualization class)

# %% [markdown]
# ### 1) Accessing the portpy data (DataExplorer class)
#  Note: you first need to download the patient database from the link provided in the GitHub page.

# %%
import sys
sys.path.append('..')

# %%
import portpy.photon as pp
import numpy as np
import os

# %%
# specify the patient data location.
data_dir = r'../data'
# Use PortPy DataExplorer class to explore PortPy data
data = pp.DataExplorer(data_dir=data_dir)
# display the existing patients in console or browser.
data.display_list_of_patients()
# Out:
#                patient_id disease_site  ptv_vol_cc  num_beams
# 0         Lung_Patient_10         Lung     308.809         72
# 1          Lung_Patient_2         Lung     737.229         72
# 2          Lung_Patient_3         Lung     160.546         72
# 3          Lung_Patient_4         Lung     312.623         72
# 4          Lung_Patient_5         Lung     323.696         72
# 5          Lung_Patient_6         Lung      87.487         72
# 6          Lung_Patient_7         Lung     177.273         72
# 7          Lung_Patient_8         Lung     614.168         72
# 8          Lung_Patient_9         Lung     173.781         72
# 9  Lung_Phantom_Patient_1         Lung      43.902         72

# %%
# pick a patient from the existing patient list to get detailed info (e.g., beam angles, structures).
data.patient_id = 'Lung_Phantom_Patient_1'
# display the data of the patient in console or browser.
beams_df, structs_df = data.display_patient_metadata(return_beams_df=True, return_structs_df=True)
beams_df.head() # head() displays only first 5 rows of beams pandas dataframe
# Out:
#    ID  gantry_angle  collimator_angle  couch_angle beam_modality energy_MV  \
# 0   0             0                 0            0        Photon         6
# 1   1             5                 0            0        Photon         6
# 2   2            10                 0            0        Photon         6
# 3   3            15                 0            0        Photon         6
# 4   4            20                 0            0        Photon         6
#
#   influence_matrix(sparse/full)  \
# 0                          Both
# 1                          Both
# 2                          Both
# 3                          Both
# 4                          Both
#
#                                           iso_center              MLC_name  \
# 0  {'x_mm': 79.47996, 'y_mm': 134.0219, 'z_mm': 3...  VARIAN MILLENIUM 120
# 1  {'x_mm': 79.47996, 'y_mm': 134.0219, 'z_mm': 3...  VARIAN MILLENIUM 120
# 2  {'x_mm': 79.47996, 'y_mm': 134.0219, 'z_mm': 3...  VARIAN MILLENIUM 120
# 3  {'x_mm': 79.47996, 'y_mm': 134.0219, 'z_mm': 3...  VARIAN MILLENIUM 120
# 4  {'x_mm': 79.47996, 'y_mm': 134.0219, 'z_mm': 3...  VARIAN MILLENIUM 120
#
#        machine_name
# 0  VARIAN TRUE BEAM
# 1  VARIAN TRUE BEAM
# 2  VARIAN TRUE BEAM
# 3  VARIAN TRUE BEAM
# 4  VARIAN TRUE BEAM

# %%
structs_df.head()
# Out:
#             name    volume_cc
# 0            GTV    27.629362
# 1  LUNGS_NOT_GTV  2983.244630
# 2            PTV    43.901787
# 3           CORD     5.307685
# 4          HEART   841.405457

# %%
# Load ct and structure set for the above patient using CT and Structures class
ct = pp.CT(data)
structs = pp.Structures(data)

# If the list of beams are not provided, it uses the beams selected manually
# by a human expert planner for the patient (manually selected beams are stored in portpy data).
# Create beams for the planner beams by default
# for the customized beams, you can pass the argument beam_ids
# e.g. beams = pp.Beams(data, beam_ids=[0,10,20,30,40,50,60])
beams = pp.Beams(data)

# create rinds based upon rind definition in optimization params
protocol_name = 'Lung_2Gy_30Fx'
opt_params = data.load_config_opt_params(protocol_name=protocol_name)
structs.create_opt_structures(opt_params=opt_params)

# load influence matrix based upon beams and structure set
inf_matrix = pp.InfluenceMatrix(ct=ct, structs=structs, beams=beams)

# load clinical criteria from the config files for which plan to be optimized
clinical_criteria = pp.ClinicalCriteria(data, protocol_name=protocol_name)
# Out:
# creating rinds.. This step may take some time due to dilation
# rinds created!!
# Creating BEV..
# Loading sparse influence matrix...
# Done

# %% [markdown]
# ### 2) Creating a simple IMRT plan using CVXPy (Plan class, Optimization class)
# Note: you can call different opensource / commercial optimization engines from CVXPy.
#   For commercial engines (e.g., Mosek, Gorubi, CPLEX), you first need to obtain an appropriate license.
#   Most commercial optimization engines give free academic license.
#
# Create my_plan object which would store all the data needed for optimization
#   (e.g., influence matrix, structures and their voxels, beams and their beamlets).

# %%
# create a plan using ct, structures, beams and influence matrix. Clinical criteria is optional
my_plan = pp.Plan(ct, structs, beams, inf_matrix, clinical_criteria)

# create cvxpy problem using the clinical criteria and optimization parameters
opt = pp.Optimization(my_plan, opt_params=opt_params)
opt.create_cvxpy_problem()
# Out:
# Objective Start
# Objective done
# Constraints Start
# Structure ESOPHAGUS not available!
# Structure ESOPHAGUS not available!
# Constraints done

# %% [markdown]
# #### Run Optimization
# - Run imrt fluence map optimization using cvxpy and one of the supported solvers and save the optimal solution in sol dictionary
# - CVXPy supports several opensource (ECOS, OSQP, SCS) and commercial solvers (e.g., MOSEK, GUROBI, CPLEX)
# - For optimization problems with non-linear objective and/or constraints, MOSEK often performs well
# - For mixed integer programs, GUROBI/CPLEX are good choices
# - If you have .edu email address, you can get free academic license for commercial solvers
# - We recommend the commercial solver MOSEK as your solver for the problems in this example,
#   however, if you don't have a license, you can try opensource/free solver SCS or ECOS
#   see [cvxpy](https://www.cvxpy.org/tutorial/advanced/index.html) for more info about CVXPy solvers
# - To set up mosek solver, you can get mosek license file using edu account and place the license file in directory C:\Users\username\mosek
#
# #### Model Formulation
#
#
# $
#    \mbox{Minimize} \quad  w_o||A_{target}\mathbf{x}-pres||_{+} + w_u||A_{target}\mathbf{x}-pres||_{-} + w_{sm}(smoothness \space objective) + w_{oar}  ||A_{oar} \mathbf{x}||
# $
#
# $
# \mbox{subject to}
# $
#
# $
# \quad maximum(A_s\mathbf{x}) \leq {d_s}^{max}
# $
#
# $
# \quad mean(A_s\mathbf{x}) \leq {d_s}^{mean}
# $
#
# $
# \quad \mathbf{x} \geq 0
# $
#
# where $w_o$ (overdose weight) = 10000 , $w_u$ (underdose weight) = 100000, $w_{sm}$ (smoothing weight) = 1000, $w_{oar}$ (oar weight) = 10, $s$ = structure index, $pres$ = prescription dose, $\mathbf{x}$ is beamlet intensity, ${d_s}^{max}$ = maximum dose for structure s, ${d_s}^{mean}$ = mean dose for structure s, $A$ = influence matrix.
#
# Smoothness objective is the total quadratic variation in beamlet intensity in x and y direction. It is given by,
#
# $
# smoothness \space objective = w_r\sum_{b\in{B}}\sum_{i\in{I_b}}(\mathbf{x}_i - \mathbf{x}_{R_i})^2 + w_l\sum_{b\in{B}}\sum_{i\in{I_b}}(\mathbf{x}_i - \mathbf{x}_{L_i})^2
# $
#
# where $w_r$ = 0.6, $w_l$=0.4, $R_i$ and $L_i$ = right and lower neigbour of beamlet i, $b$ = beam number, $I_b$ = beamlet indices of beam $b$

# %%
sol = opt.solve(solver='MOSEK', verbose=True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Jul 05 11:51:44 AM: Your problem has 1946 variables, 14 constraints, and 0 parameters.
# (CVXPY) Jul 05 11:51:44 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 05 11:51:44 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 05 11:51:44 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 05 11:51:44 AM: Compiling problem (target solver=MOSEK).
# (CVXPY) Jul 05 11:51:44 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Jul 05 11:51:44 AM: Applying reduction Dcp2Cone
# (CVXPY) Jul 05 11:51:44 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 05 11:51:44 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jul 05 11:51:48 AM: Applying reduction MOSEK
# (CVXPY) Jul 05 11:51:49 AM: Finished problem compilation (took 4.314e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 05 11:51:49 AM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Jul 05 11:51:50 AM: Problem
# (CVXPY) Jul 05 11:51:50 AM:   Name                   :
# (CVXPY) Jul 05 11:51:50 AM:   Objective sense        : maximize
# (CVXPY) Jul 05 11:51:50 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Jul 05 11:51:50 AM:   Constraints            : 1959
# (CVXPY) Jul 05 11:51:50 AM:   Affine conic cons.     : 0
# (CVXPY) Jul 05 11:51:50 AM:   Disjunctive cons.      : 0
# (CVXPY) Jul 05 11:51:50 AM:   Cones                  : 13
# (CVXPY) Jul 05 11:51:50 AM:   Scalar variables       : 215748
# (CVXPY) Jul 05 11:51:50 AM:   Matrix variables       : 0
# (CVXPY) Jul 05 11:51:50 AM:   Integer variables      : 0
# (CVXPY) Jul 05 11:51:50 AM:
# (CVXPY) Jul 05 11:51:50 AM: Optimizer started.
# (CVXPY) Jul 05 11:51:51 AM: Presolve started.
# (CVXPY) Jul 05 11:51:51 AM: Linear dependency checker started.
# (CVXPY) Jul 05 11:51:51 AM: Linear dependency checker terminated.
# (CVXPY) Jul 05 11:51:51 AM: Eliminator started.
# (CVXPY) Jul 05 11:51:51 AM: Freed constraints in eliminator : 0
# (CVXPY) Jul 05 11:51:51 AM: Eliminator terminated.
# (CVXPY) Jul 05 11:51:51 AM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Jul 05 11:51:51 AM: Lin. dep.  - tries                  : 1                 time                   : 0.03
# (CVXPY) Jul 05 11:51:51 AM: Lin. dep.  - number                 : 0
# (CVXPY) Jul 05 11:51:51 AM: Presolve terminated. Time: 0.64
# (CVXPY) Jul 05 11:51:52 AM: Problem
# (CVXPY) Jul 05 11:51:52 AM:   Name                   :
# (CVXPY) Jul 05 11:51:52 AM:   Objective sense        : maximize
# (CVXPY) Jul 05 11:51:52 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Jul 05 11:51:52 AM:   Constraints            : 1959
# (CVXPY) Jul 05 11:51:52 AM:   Affine conic cons.     : 0
# (CVXPY) Jul 05 11:51:52 AM:   Disjunctive cons.      : 0
# (CVXPY) Jul 05 11:51:52 AM:   Cones                  : 13
# (CVXPY) Jul 05 11:51:52 AM:   Scalar variables       : 215748
# (CVXPY) Jul 05 11:51:52 AM:   Matrix variables       : 0
# (CVXPY) Jul 05 11:51:52 AM:   Integer variables      : 0
# (CVXPY) Jul 05 11:51:52 AM:
# (CVXPY) Jul 05 11:51:52 AM: Optimizer  - threads                : 16
# (CVXPY) Jul 05 11:51:52 AM: Optimizer  - solved problem         : the primal
# (CVXPY) Jul 05 11:51:52 AM: Optimizer  - Constraints            : 1959
# (CVXPY) Jul 05 11:51:52 AM: Optimizer  - Cones                  : 13
# (CVXPY) Jul 05 11:51:52 AM: Optimizer  - Scalar variables       : 80782             conic                  : 50518
# (CVXPY) Jul 05 11:51:52 AM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Jul 05 11:51:52 AM: Factor     - setup time             : 0.52              dense det. time        : 0.00
# (CVXPY) Jul 05 11:51:52 AM: Factor     - ML order time          : 0.17              GP order time          : 0.00
# (CVXPY) Jul 05 11:51:52 AM: Factor     - nonzeros before factor : 2.46e+05          after factor           : 2.47e+05
# (CVXPY) Jul 05 11:51:52 AM: Factor     - dense dim.             : 4                 flops                  : 8.22e+07
# (CVXPY) Jul 05 11:51:52 AM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Jul 05 11:51:52 AM: 0   1.4e+02  4.6e+02  1.4e+01  0.00e+00   -1.300000000e+01  0.000000000e+00   1.0e+00  1.59
# (CVXPY) Jul 05 11:51:52 AM: 1   1.2e+02  4.1e+02  1.3e+01  -9.86e-01  4.131473144e+03   4.144316302e+03   8.8e-01  1.77
# (CVXPY) Jul 05 11:51:52 AM: 2   6.8e+01  2.2e+02  9.5e+00  -9.79e-01  3.094326949e+04   3.095500114e+04   4.8e-01  1.89
# (CVXPY) Jul 05 11:51:53 AM: 3   3.7e+01  1.2e+02  6.7e+00  -9.13e-01  2.557584936e+04   2.558558020e+04   2.6e-01  2.03
# (CVXPY) Jul 05 11:51:53 AM: 4   1.4e+01  4.5e+01  3.3e+00  -7.64e-01  1.640479432e+04   1.640934897e+04   9.8e-02  2.14
# (CVXPY) Jul 05 11:51:53 AM: 5   5.6e+00  1.8e+01  1.3e+00  -3.34e-01  1.093889194e+04   1.093978543e+04   4.0e-02  2.28
# (CVXPY) Jul 05 11:51:53 AM: 6   2.3e+00  7.5e+00  4.3e-01  1.75e-01   6.846000428e+03   6.845975883e+03   1.6e-02  2.41
# (CVXPY) Jul 05 11:51:53 AM: 7   8.9e-01  2.9e+00  1.1e-01  5.88e-01   3.360682466e+03   3.360609709e+03   6.3e-03  2.56
# (CVXPY) Jul 05 11:51:53 AM: 8   3.5e-01  1.2e+00  3.0e-02  8.33e-01   1.471831416e+03   1.471769013e+03   2.5e-03  2.70
# (CVXPY) Jul 05 11:51:53 AM: 9   1.3e-01  4.4e-01  7.2e-03  9.37e-01   5.963000267e+02   5.962595743e+02   9.5e-04  2.84
# (CVXPY) Jul 05 11:51:53 AM: 10  5.4e-02  1.8e-01  1.9e-03  9.80e-01   2.794354503e+02   2.794136331e+02   3.8e-04  2.98
# (CVXPY) Jul 05 11:51:54 AM: 11  1.9e-02  6.3e-02  4.1e-04  9.94e-01   1.242764277e+02   1.242668016e+02   1.4e-04  3.14
# (CVXPY) Jul 05 11:51:54 AM: 12  7.8e-03  2.5e-02  1.1e-04  1.00e+00   7.813161372e+01   7.812729158e+01   5.5e-05  3.28
# (CVXPY) Jul 05 11:51:54 AM: 13  2.8e-03  9.1e-03  2.3e-05  1.00e+00   5.422719759e+01   5.422550144e+01   2.0e-05  3.41
# (CVXPY) Jul 05 11:51:54 AM: 14  1.3e-03  4.1e-03  7.1e-06  1.00e+00   4.690658089e+01   4.690577191e+01   8.9e-06  3.55
# (CVXPY) Jul 05 11:51:54 AM: 15  4.3e-04  1.4e-03  1.4e-06  9.99e-01   4.377742727e+01   4.377714148e+01   3.0e-06  3.69
# (CVXPY) Jul 05 11:51:54 AM: 16  1.4e-04  4.7e-04  2.8e-07  9.99e-01   4.262818861e+01   4.262808998e+01   1.0e-06  3.83
# (CVXPY) Jul 05 11:51:54 AM: 17  6.3e-05  2.1e-04  8.1e-08  9.99e-01   4.229317671e+01   4.229313227e+01   4.5e-07  3.95
# (CVXPY) Jul 05 11:51:55 AM: 18  1.6e-05  5.2e-05  1.0e-08  1.00e+00   4.210759535e+01   4.210758419e+01   1.1e-07  4.09
# (CVXPY) Jul 05 11:51:55 AM: 19  2.3e-06  7.4e-06  5.5e-10  1.00e+00   4.205327962e+01   4.205327797e+01   1.6e-08  4.22
# (CVXPY) Jul 05 11:51:55 AM: 20  8.7e-07  2.8e-06  1.3e-10  1.00e+00   4.204836718e+01   4.204836653e+01   6.2e-09  4.36
# (CVXPY) Jul 05 11:51:55 AM: 21  3.2e-07  1.1e-06  3.0e-11  1.00e+00   4.204651069e+01   4.204651045e+01   2.3e-09  4.53
# (CVXPY) Jul 05 11:51:55 AM: 22  2.0e-07  3.6e-07  5.1e-12  9.41e-01   4.204567265e+01   4.204567260e+01   6.7e-10  4.66
# (CVXPY) Jul 05 11:51:55 AM: 23  9.5e-08  5.1e-07  9.7e-13  1.21e+00   4.204548363e+01   4.204548360e+01   2.6e-10  4.92
# (CVXPY) Jul 05 11:51:56 AM: 24  2.2e-08  7.6e-07  1.3e-13  9.98e-01   4.204539261e+01   4.204539261e+01   7.0e-11  5.20
# (CVXPY) Jul 05 11:51:56 AM: Optimizer terminated. Time: 5.31
# (CVXPY) Jul 05 11:51:56 AM:
# (CVXPY) Jul 05 11:51:56 AM:
# (CVXPY) Jul 05 11:51:56 AM: Interior-point solution summary
# (CVXPY) Jul 05 11:51:56 AM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Jul 05 11:51:56 AM:   Solution status : OPTIMAL
# (CVXPY) Jul 05 11:51:56 AM:   Primal.  obj: 4.2045392615e+01    nrm: 1e+02    Viol.  con: 2e-06    var: 6e-07    cones: 0e+00
# (CVXPY) Jul 05 11:51:56 AM:   Dual.    obj: 4.2045392607e+01    nrm: 6e+03    Viol.  con: 0e+00    var: 3e-09    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 05 11:51:56 AM: Problem status: optimal
# (CVXPY) Jul 05 11:51:56 AM: Optimal value: 4.205e+01
# (CVXPY) Jul 05 11:51:56 AM: Compilation took 4.314e+00 seconds
# (CVXPY) Jul 05 11:51:56 AM: Solver (including time spent in interface) took 7.136e+00 seconds

# %% [markdown]
# ### 3) Visualizing the plan (Visualization class)

# %%
# plot fluence 3d and 2d for the 1st beam
pp.Visualization.plot_fluence_3d(sol=sol, beam_id=my_plan.beams.get_all_beam_ids()[0])

pp.Visualization.plot_fluence_2d(sol=sol, beam_id=my_plan.beams.get_all_beam_ids()[0])
# Out:
# <Axes: xlabel='x-axis (beamlets column)', ylabel='y-axis (beamlets row)'>

# %%
# plot dvh for the structures in the given list. Default dose_1d is in Gy and volume is in relative scale(%).
struct_names = ['PTV', 'ESOPHAGUS', 'HEART', 'CORD']

# plot dvh for the above structures
pp.Visualization.plot_dvh(my_plan, sol=sol, struct_names=struct_names, title=data.patient_id)
# Out:
# <Axes: title={'center': 'Lung_Phantom_Patient_1'}, xlabel='Dose (Gy)', ylabel='Volume Fraction (%)'>

# %%
# plot 2d axial slice for the given solution and display the structures contours on the slice
pp.Visualization.plot_2d_slice(my_plan=my_plan, sol=sol, slice_num=60, struct_names=['PTV'])
# Out:
# <Axes: title={'center': 'Axial View - Slice #: 60'}>

# %% [markdown]
# ### 4) Evaluating the plan (Evaluation class)

# %%
# visualize plan metrics based upon clinical criteria
pp.Evaluation.display_clinical_criteria(my_plan, sol=sol)
# Out:
# <style type="text/css">
# #T_bf301_row0_col3, #T_bf301_row1_col3, #T_bf301_row2_col3, #T_bf301_row3_col3, #T_bf301_row4_col3, #T_bf301_row5_col3, #T_bf301_row6_col3, #T_bf301_row7_col3, #T_bf301_row8_col3, #T_bf301_row9_col3, #T_bf301_row10_col3, #T_bf301_row11_col3, #T_bf301_row12_col3, #T_bf301_row13_col3, #T_bf301_row14_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_bf301">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf301_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_bf301_level0_col1" class="col_heading level0 col1" >parameters</th>
#       <th id="T_bf301_level0_col2" class="col_heading level0 col2" >constraints</th>
#       <th id="T_bf301_level0_col3" class="col_heading level0 col3" >Plan Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf301_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf301_row0_col0" class="data row0 col0" >max_dose</td>
#       <td id="T_bf301_row0_col1" class="data row0 col1" >{'structure_name': 'GTV'}</td>
#       <td id="T_bf301_row0_col2" class="data row0 col2" >{'limit_dose_gy': 69, 'goal_dose_gy': 66}</td>
#       <td id="T_bf301_row0_col3" class="data row0 col3" >65.960525</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf301_row1_col0" class="data row1 col0" >max_dose</td>
#       <td id="T_bf301_row1_col1" class="data row1 col1" >{'structure_name': 'PTV'}</td>
#       <td id="T_bf301_row1_col2" class="data row1 col2" >{'limit_dose_gy': 69, 'goal_dose_gy': 66}</td>
#       <td id="T_bf301_row1_col3" class="data row1 col3" >65.960525</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bf301_row2_col0" class="data row2 col0" >max_dose</td>
#       <td id="T_bf301_row2_col1" class="data row2 col1" >{'structure_name': 'HEART'}</td>
#       <td id="T_bf301_row2_col2" class="data row2 col2" >{'limit_dose_gy': 66}</td>
#       <td id="T_bf301_row2_col3" class="data row2 col3" >59.355806</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bf301_row3_col0" class="data row3 col0" >mean_dose</td>
#       <td id="T_bf301_row3_col1" class="data row3 col1" >{'structure_name': 'HEART'}</td>
#       <td id="T_bf301_row3_col2" class="data row3 col2" >{'limit_dose_gy': 27, 'goal_dose_gy': 20}</td>
#       <td id="T_bf301_row3_col3" class="data row3 col3" >4.756927</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bf301_row4_col0" class="data row4 col0" >dose_volume_V</td>
#       <td id="T_bf301_row4_col1" class="data row4 col1" >{'structure_name': 'HEART', 'dose_gy': 30}</td>
#       <td id="T_bf301_row4_col2" class="data row4 col2" >{'limit_volume_perc': 50}</td>
#       <td id="T_bf301_row4_col3" class="data row4 col3" >1.433088</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bf301_row5_col0" class="data row5 col0" >dose_volume_V</td>
#       <td id="T_bf301_row5_col1" class="data row5 col1" >{'structure_name': 'HEART', 'dose_gy': 30}</td>
#       <td id="T_bf301_row5_col2" class="data row5 col2" >{'goal_volume_perc': 48}</td>
#       <td id="T_bf301_row5_col3" class="data row5 col3" >1.433088</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bf301_row6_col0" class="data row6 col0" >max_dose</td>
#       <td id="T_bf301_row6_col1" class="data row6 col1" >{'structure_name': 'LUNG_L'}</td>
#       <td id="T_bf301_row6_col2" class="data row6 col2" >{'limit_dose_gy': 66}</td>
#       <td id="T_bf301_row6_col3" class="data row6 col3" >65.960525</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bf301_row7_col0" class="data row7 col0" >max_dose</td>
#       <td id="T_bf301_row7_col1" class="data row7 col1" >{'structure_name': 'LUNG_R'}</td>
#       <td id="T_bf301_row7_col2" class="data row7 col2" >{'limit_dose_gy': 66}</td>
#       <td id="T_bf301_row7_col3" class="data row7 col3" >25.475052</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bf301_row8_col0" class="data row8 col0" >max_dose</td>
#       <td id="T_bf301_row8_col1" class="data row8 col1" >{'structure_name': 'CORD'}</td>
#       <td id="T_bf301_row8_col2" class="data row8 col2" >{'limit_dose_gy': 50, 'goal_dose_gy': 48}</td>
#       <td id="T_bf301_row8_col3" class="data row8 col3" >10.729661</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bf301_row9_col0" class="data row9 col0" >max_dose</td>
#       <td id="T_bf301_row9_col1" class="data row9 col1" >{'structure_name': 'SKIN'}</td>
#       <td id="T_bf301_row9_col2" class="data row9 col2" >{'limit_dose_gy': 60}</td>
#       <td id="T_bf301_row9_col3" class="data row9 col3" >50.963999</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bf301_row10_col0" class="data row10 col0" >max_dose</td>
#       <td id="T_bf301_row10_col1" class="data row10 col1" >{'structure_name': 'RIND_0'}</td>
#       <td id="T_bf301_row10_col2" class="data row10 col2" >{'limit_dose_gy': 66.0}</td>
#       <td id="T_bf301_row10_col3" class="data row10 col3" >65.490272</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bf301_row11_col0" class="data row11 col0" >max_dose</td>
#       <td id="T_bf301_row11_col1" class="data row11 col1" >{'structure_name': 'RIND_1'}</td>
#       <td id="T_bf301_row11_col2" class="data row11 col2" >{'limit_dose_gy': 63.0}</td>
#       <td id="T_bf301_row11_col3" class="data row11 col3" >61.958793</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bf301_row12_col0" class="data row12 col0" >max_dose</td>
#       <td id="T_bf301_row12_col1" class="data row12 col1" >{'structure_name': 'RIND_2'}</td>
#       <td id="T_bf301_row12_col2" class="data row12 col2" >{'limit_dose_gy': 54.0}</td>
#       <td id="T_bf301_row12_col3" class="data row12 col3" >53.999999</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bf301_row13_col0" class="data row13 col0" >max_dose</td>
#       <td id="T_bf301_row13_col1" class="data row13 col1" >{'structure_name': 'RIND_3'}</td>
#       <td id="T_bf301_row13_col2" class="data row13 col2" >{'limit_dose_gy': 51.0}</td>
#       <td id="T_bf301_row13_col3" class="data row13 col3" >50.999999</td>
#     </tr>
#     <tr>
#       <th id="T_bf301_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bf301_row14_col0" class="data row14 col0" >max_dose</td>
#       <td id="T_bf301_row14_col1" class="data row14 col1" >{'structure_name': 'RIND_4'}</td>
#       <td id="T_bf301_row14_col2" class="data row14 col2" >{'limit_dose_gy': 45.0}</td>
#       <td id="T_bf301_row14_col3" class="data row14 col3" >44.999994</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 5) Saving and loading the plan for future use (utils)

# %%
# Comment/Uncomment these lines to save and load the pickle file for plans and optimal solution from the directory
pp.save_plan(my_plan, plan_name='my_plan_phantom.pkl', path=os.path.join(r'C:\temp', data.patient_id))
pp.save_optimal_sol(sol, sol_name='sol_phantom.pkl', path=os.path.join(r'C:\temp', data.patient_id))
# my_plan = pp.load_plan(plan_name='my_plan_phantom.pkl', path=os.path.join(r'C:\temp', data.patient_id))
# sol = pp.load_optimal_sol(sol_name='sol_phantom.pkl', path=os.path.join(r'C:\temp', data.patient_id))

# %% [markdown]
# ### 6) Advanced visualization with 3D-Slicer (Visualization class)

# %%
# Note: This requires downloading and installing 3d slicer
#   3D slicer integration is seamless with Jupiter Notebook (see ex_7_Slicer).
# Without Jupiter Notebook, we first need to save our data (ct, 3D dose, structures)
#   as images in nrrd format on disk and then lunch Slicer by providing data as input argument
pp.save_nrrd(my_plan, sol=sol, data_dir=os.path.join(r'C:\temp', data.patient_id))
pp.Visualization.view_in_slicer(my_plan, slicer_path=r'C:\ProgramData\NA-MIC\Slicer 5.2.1\Slicer.exe',
                                data_dir=os.path.join(r'C:\temp', data.patient_id))
print('Done!')
# Out:
# Done
# Done!
